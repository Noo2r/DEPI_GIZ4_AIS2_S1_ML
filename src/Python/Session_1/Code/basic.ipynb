# %%
print("Hello World")
# Out:
# Hello World

# %%
print("My name is {x}, I am {y} years old, I am engaged in learning {z} <3 ".format(x="Nour Eldin Ahmed",y=21, z="DEPI ML With ENG.George"))
# Out:
# My name is Nour Eldin Ahmed, I am 21 years old, I am engaged in learning DEPI ML With ENG.George <3

# %%
name = "amit learning"
print(name[5:10:1])
# Out:
# learn

# %%
print("hello\nnour")
# Out:
# hello
# nour

# %%
print("Hello\tmeeee")
# Out:
# Hello	meeee

# %%
x= 2
print(bin(x))
# Out:
# 0b10
