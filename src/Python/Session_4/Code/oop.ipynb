# %%
"""
this class holds student information

"""
class Student_Info:

    std_name = "Nour Eldin"
    std_age = 21
    std_gpa = 3.99
    std_gender = "Male"

    def std_info(self):
        print("Student Name:", Student_Info.std_name)
        print("Student Age:", Student_Info.std_age)
        print("Student GPA:", Student_Info.std_gpa)
        print("Student Gender:", Student_Info.std_gender)

# %%
s1 = Student_Info()
s1.std_info()
# Out:
# Student Name: Nour Eldin
# Student Age: 21
# Student GPA: 3.99
# Student Gender: Male

# %%
class Student_Course:

    def __init__(self):
        self.course_name = "Machine Learning"
        self.course_code = "ML101"
        self.course_credit = 3

# %%
import random 
"""
this class generate a random password 
and has a 2 methods
- __init__ : to initialize the length and characters
- generate_password : to generate the password
"""
class PasswordGenerator:
    
    def __init__(self,length):
        self.length = length
        self.characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"

    def generate_password(self,length):
        char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"
        password = ''.join(random.choice(char) for i in range(self.length))
        return password
    
if __name__ == "__main__":
    pg = PasswordGenerator(12)
    print("Generated Password:", pg.generate_password(12))
# Out:
# Generated Password: p#pJT2Sd1XN4

# %% [markdown]
# # Abstractmethod

# %%
from abc import ABC, abstractmethod
"""
this is an abstract class for arithmetic operations
"""

class animal(ABC):

    @abstractmethod
    def sound(self):
        pass

class Dog(animal):

    def sound(self):
        print("Woof")

class Cat(animal):
    def sound(self):
        print("Meow")

# %%
a = Dog()
a.sound()
# Out:
# Woof

# %%
class a():
    def play(self):
        print("Playing A")

class b(a):
    pass

class c():
    def play(self):
        print("Playing C")

class d(b,a):
    pass

# %%
d1 = d()
d1.play()
# Out:
# Playing A

# %% [markdown]
# # ERROR Handeling

# %%
# Exception Handling Example
try:
    x = 10 / 0 
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

# %%
try:
    x = 10 
    y = int(input("Enter a number to divide 10 by: "))
    result = x / y
    print("Result:", result)
except Exception as e:
    print(e)

# %% [markdown]
# # Read File

# %%
import os

# %%
base = "C:/Users/LOQ/OneDrive - Arab Academy for Science and Technology/DEPI/GIZ4_AIS2_S1_ML/src/Python/Session_4"
type(base)
# Out:
# str

# %%
os.listdir(base)
# Out:
# ['assignment', 'Code', 'Materail']

# %%
file = base 
print((file))

# %%
import os

directory = "C:/Users/LOQ/OneDrive - Arab Academy for Science and Technology/DEPI/GIZ4_AIS2_S1_ML/src/Python/Session_4/newfolder"

if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("directory is already exists: ", directory)

# %%
from create_folder import create_folders

# %%
with open("C:/Users/LOQ/OneDrive - Arab Academy for Science and Technology/DEPI/GIZ4_AIS2_S1_ML/src/Python/Session_4/newfolder/text_1.txt", "a+") as file:

    file.write("new line \n")
    file.seek(0)
    updated_content = file.read()

    print(updated_content)
# Out:
# new line

# %% [markdown]
# # Small program
# for username and password verification

# %%
# !pip install prettytable
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random

from prettytable import PrettyTable

user = "test"
password = "1234"

while True:
    x = input("Enter your username:")

    if x == user:
        y = input("Enter your password: ")
        if y == password:
            s = random.randrange(10000,1000000)
            print("verification code is: ", s)
            while True:
                l = int(input("Enter verification code: "))
                if l == s:
                    print(f"Access Granted! \n Welcome {user}")
                    break
                else:
                    print("Invalid verification code")
            break
        else:
            print("Incorrect password. please try again")
            continue
    else:
        print("Incorrect username. please try again")
        continue
# Out:
# verification code is:  761190
# Access Granted!
#  Welcome test
