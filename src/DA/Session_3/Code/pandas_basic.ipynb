# %%
print("Hello Pandas!")
# Out:
# Hello Pandas!

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = [
    [1, 'Alice', 25],
    [2, 'Bob', 30],
    [3, 'Charlie', 35],
    [4, 'David', 40]
]
df = pd.DataFrame(data, columns=['ID', 'Name', 'Age'])
df
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 3   4    David   40

# %%
data_dict = {
    'ID': [1, 2, 3, 4],
    'Salary': [50000, 60000, 70000, 80000],
    'Department': ['HR', 'Finance', 'IT', 'Marketing']
    }

df2 = pd.DataFrame(data_dict)
display(df2)
df2.columns
df2.shape
df2.dtypes
# Out:
#    ID  Salary Department
# 0   1   50000         HR
# 1   2   60000    Finance
# 2   3   70000         IT
# 3   4   80000  Marketing
# ID            int64
# Salary        int64
# Department      str
# dtype: object

# %%
df2['Salary']
# Out:
# 0    50000
# 1    60000
# 2    70000
# 3    80000
# Name: Salary, dtype: int64

# %%
def chk(df,type):
    return df[type].dtype

# %%
df2['Department'] = df2['Department'].astype('category')
chk(df2,'Department')
# Out:
# CategoricalDtype(categories=['Finance', 'HR', 'IT', 'Marketing'], ordered=False, categories_dtype=str)

# %%
df2.describe()
# Out:
#              ID        Salary
# count  4.000000      4.000000
# mean   2.500000  65000.000000
# std    1.290994  12909.944487
# min    1.000000  50000.000000
# 25%    1.750000  57500.000000
# 50%    2.500000  65000.000000
# 75%    3.250000  72500.000000
# max    4.000000  80000.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age'], dtype='str')

# %%
df['Age'].unique()
# Out:
# array([25, 30, 35, 40])

# %%
df2['Salary'].nunique()
# Out:
# 4

# %%
df2['Salary'].max()
# Out:
# np.int64(80000)

# %%
df2['Salary'].min()
# Out:
# np.int64(50000)

# %%
df2['Salary'].idxmax()
# Out:
# 3

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          4 non-null      int64
#  1   Salary      4 non-null      int64
#  2   Department  4 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 232.0 bytes

# %%
df2['Salary'].sum()
# Out:
# np.int64(260000)

# %%
df2['Salary'].values
# Out:
# array([50000, 60000, 70000, 80000])

# %%
df2.values
# Out:
# array([[1, 50000, 'HR'],
#        [2, 60000, 'Finance'],
#        [3, 70000, 'IT'],
#        [4, 80000, 'Marketing']], dtype=object)

# %%
df2.replace(60000, 65000)
# Out:
#    ID  Salary Department
# 0   1   50000         HR
# 1   2   65000    Finance
# 2   3   70000         IT
# 3   4   80000  Marketing

# %%
df.iloc[2,1]
# Out:
# 'Charlie'

# %%
df['Age'].iloc[0:2]
# Out:
# 0    25
# 1    30
# Name: Age, dtype: int64

# %%
df.iloc[:, 0:2]
# Out:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David

# %%
null = df.isnull()
null.sum()
# Out:
# ID      0
# Name    0
# Age     0
# dtype: int64

# %%
import numpy as np
data = [
    [1, 'Alice', 25],
    [np.nan, 'Bob', 30],
    [3, 'Charlie', 35],
    [4, 'David', np.nan]
]
df = pd.DataFrame(data, columns=['ID', 'Name', 'Age'])
df
# Out:
#     ID     Name   Age
# 0  1.0    Alice  25.0
# 1  NaN      Bob  30.0
# 2  3.0  Charlie  35.0
# 3  4.0    David   NaN

# %%
null = df.isnull().sum()
pd.DataFrame(null).T
# Out:
#    ID  Name  Age
# 0   1     0    1

# %%
df.dropna()
# Out:
#     ID     Name   Age
# 0  1.0    Alice  25.0
# 2  3.0  Charlie  35.0

# %%
df.dropna(subset=['ID'])
# Out:
#     ID     Name   Age
# 0  1.0    Alice  25.0
# 2  3.0  Charlie  35.0
# 3  4.0    David   NaN

# %%
mean = df['Age'].mean()
df['Age'] = df['Age'].fillna(value=mean)
df
# Out:
#     ID     Name   Age
# 0  1.0    Alice  25.0
# 1  NaN      Bob  30.0
# 2  3.0  Charlie  35.0
# 3  4.0    David  30.0

# %%
Header_col = ['index','age','gender','dept','postal code']
data=pd.read_table('http://bit.ly/movieusers',sep='|',header=None,names=Header_col)
data
# Out:
#      index  age gender           dept postal code
# 0        1   24      M     technician       85711
# 1        2   53      F          other       94043
# 2        3   23      M         writer       32067
# 3        4   24      M     technician       43537
# 4        5   33      F          other       15213
# ..     ...  ...    ...            ...         ...
# 938    939   26      F        student       33319
# 939    940   32      M  administrator       02215
# 940    941   20      M        student       97229
# 941    942   48      F      librarian       78209
# 942    943   22      M        student       77841
#
# [943 rows x 5 columns]

# %%
user_info=pd.read_csv('http://bit.ly/uforeports')
user_info.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
user_info.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  str
#  1   Colors Reported  2882 non-null   str
#  2   Shape Reported   15597 non-null  str
#  3   State            18241 non-null  str
#  4   Time             18241 non-null  str
# dtypes: str(5)
# memory usage: 712.7 KB

# %%
user_info['Location'] = user_info.City + ', ' + user_info.State
user_info.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
user_info.rename(columns={'Colors Reported':'Colors_Reported'})
# Out:
#                        City Colors_Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                  Location
# 0        6/1/1930 22:00                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ
# ...

# %%
user_info.columns = user_info.columns.str.replace(' ', '_')
user_info.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time',
#        'Location'],
#       dtype='str')

# %%
user_info.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
# drop a city column
user_info.drop(columns=['City'])
# Out:
#       Colors_Reported Shape_Reported State              Time  \
# 0                 NaN       TRIANGLE    NY    6/1/1930 22:00
# 1                 NaN          OTHER    NJ   6/30/1930 20:00
# 2                 NaN           OVAL    CO   2/15/1931 14:00
# 3                 NaN           DISK    KS    6/1/1931 13:00
# 4                 NaN          LIGHT    NY   4/18/1933 19:00
# ...               ...            ...   ...               ...
# 18236             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237             NaN           DISK    IA  12/31/2000 23:00
# 18238             NaN            NaN    WI  12/31/2000 23:45
# 18239             RED          LIGHT    WI  12/31/2000 23:45
# 18240             NaN           OVAL    FL  12/31/2000 23:59
#
#                        Location
# 0                    Ithaca, NY
# 1               Willingboro, NJ
# 2                   Holyoke, CO
# 3                   Abilene, KS
# 4      New York Worlds Fair, NY
# ...                         ...
# ...

# %%
user_info.to_csv('test.csv')
